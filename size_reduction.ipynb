# %%
import os
from PIL import Image
import time

def compress_images_recursive(root_folder, max_size_mb=4):
    max_size = max_size_mb * 1024 * 1024  # 바이트로 변환

    for dirpath, _, filenames in os.walk(root_folder):
        for filename in filenames:
            if not filename.lower().endswith(".jpg"):
                continue

            filepath = os.path.join(dirpath, filename)
            filesize = os.path.getsize(filepath)

            if filesize <= max_size:
                print(f"✅ {filename}: {filesize/1024:.1f}KB → 유지")
                continue

            try:
                img = Image.open(filepath).convert("RGB")  # ✅ RGB 강제 변환
                quality = 95
                step = 5
                compressed = False

                for _ in range(10):
                    temp_path = filepath + ".temp.jpg"
                    img.save(temp_path, format="JPEG", quality=quality, optimize=True)

                    time.sleep(0.1)  # 파일 저장 안정화
                    temp_size = os.path.getsize(temp_path)

                    if temp_size <= max_size:
                        img.close()
                        os.remove(filepath)  # 원본 삭제
                        os.rename(temp_path, filepath)  # ✅ 안전하게 교체
                        print(f"⚠️ {filename}: 압축됨 → {temp_size/1024:.1f}KB (quality={quality})")
                        compressed = True
                        break

                    quality -= step

                if not compressed:
                    img.close()
                    if os.path.exists(temp_path):
                        os.remove(temp_path)
                    print(f"❌ {filename}: 압축 실패 (최저 quality={quality + step})")

            except Exception as e:
                print(f"❌ {filename}: 처리 중 오류 발생 → {e}")

# %%
compress_images_recursive("heavy")    # 바꾸고 싶은 폴더주소 입력
# Out:
# ⚠️ IMG_9351.JPG: 압축됨 → 4021.9KB (quality=85)
# ⚠️ IMG_9352.JPG: 압축됨 → 3955.9KB (quality=85)
# ⚠️ IMG_9355.JPG: 압축됨 → 3946.8KB (quality=85)
# ⚠️ IMG_9358.JPG: 압축됨 → 3600.6KB (quality=80)
# ⚠️ IMG_9363.JPG: 압축됨 → 3637.3KB (quality=85)
# ⚠️ IMG_9366.JPG: 압축됨 → 4076.9KB (quality=85)
# ⚠️ IMG_9375.JPG: 압축됨 → 3227.3KB (quality=85)
# ⚠️ IMG_9404.JPG: 압축됨 → 3673.2KB (quality=85)
# ⚠️ IMG_9405.JPG: 압축됨 → 3490.8KB (quality=85)
# ⚠️ IMG_9406.JPG: 압축됨 → 3630.3KB (quality=85)
# ⚠️ IMG_9411.JPG: 압축됨 → 3969.0KB (quality=90)
# ⚠️ IMG_9412.JPG: 압축됨 → 3436.5KB (quality=85)
# ⚠️ IMG_9420.JPG: 압축됨 → 3574.8KB (quality=85)
# ⚠️ IMG_9426.JPG: 압축됨 → 3509.3KB (quality=85)
# ✅ IMG_9433.JPG: 2834.5KB → 유지
# ⚠️ IMG_9434.JPG: 압축됨 → 3347.1KB (quality=85)
# ⚠️ IMG_9441.JPG: 압축됨 → 3192.0KB (quality=85)
# ⚠️ IMG_9442.JPG: 압축됨 → 3714.3KB (quality=90)
# ⚠️ IMG_9443.JPG: 압축됨 → 3760.7KB (quality=85)
# ⚠️ IMG_9446.JPG: 압축됨 → 3604.3KB (quality=85)
# ⚠️ IMG_9472.JPG: 압축됨 → 3926.2KB (quality=90)
# ⚠️ IMG_9474.JPG: 압축됨 → 4064.7KB (quality=90)
# ⚠️ IMG_9476.JPG: 압축됨 → 3836.8KB (quality=90)
# ⚠️ IMG_9477.JPG: 압축됨 → 3781.5KB (quality=90)
# ⚠️ IMG_9480.JPG: 압축됨 → 3397.0KB (quality=90)
# ⚠️ IMG_9486.JPG: 압축됨 → 3507.4KB (quality=90)
# ⚠️ IMG_9488.JPG: 압축됨 → 3643.1KB (quality=90)
# ⚠️ IMG_9489.JPG: 압축됨 → 4001.0KB (quality=90)
# ✅ IMG_9511.JPG: 4049.3KB → 유지
# ✅ IMG_9514.JPG: 4040.5KB → 유지
# ✅ IMG_9516.JPG: 3882.5KB → 유지
# ⚠️ IMG_9517.JPG: 압축됨 → 3940.4KB (quality=90)
# ⚠️ IMG_9518.JPG: 압축됨 → 3136.9KB (quality=85)
# ⚠️ IMG_9522.JPG: 압축됨 → 3844.8KB (quality=90)
# ✅ IMG_9523.JPG: 3569.2KB → 유지
# ✅ IMG_9524.JPG: 4093.7KB → 유지
# ✅ IMG_9543.JPG: 3906.9KB → 유지
# ✅ IMG_9547.JPG: 3268.3KB → 유지
# ✅ IMG_9548.JPG: 3175.6KB → 유지
# ✅ IMG_9549.JPG: 3564.0KB → 유지
# ⚠️ IMG_9550.JPG: 압축됨 → 3721.0KB (quality=90)
# ✅ IMG_9551.JPG: 3847.0KB → 유지
# ⚠️ IMG_9552.JPG: 압축됨 → 3760.0KB (quality=90)
